# %% [markdown]
# ### LOANS are the major requirement of the modern world. By this only, Banks get a major part of the total profit. It is beneficial for students to manage their education and living expenses, and for people to buy any kind of luxury like houses, cars, etc.
#
# But when it comes to deciding whether the applicant’s profile is relevant to be granted with loan or not. Banks have to look after many aspects.
#
# So, here we will be using Machine Learning with Python to ease their work and predict whether the candidate’s profile is relevant or not using key features like Marital Status, Education, Applicant Income, Credit History, etc.

# %% [markdown]
# The dataset contains 13 features :
#
# - 1	Loan	A unique id
# - 2	Gender	Gender of the applicant Male/female
# - 3	Married	Marital Status of the applicant, values will be Yes/ No
# - 4	Dependents	It tells whether the applicant has any dependents or not.
# - 5	Education	It will tell us whether the applicant is Graduated or not.
# - 6	Self_Employed	This defines that the applicant is self-employed i.e. Yes/ No
# - 7	ApplicantIncome	Applicant income
# - 8	CoapplicantIncome	Co-applicant income
# - 9	LoanAmount	Loan amount (in thousands)
# - 10	Loan_Amount_Term	Terms of loan (in months)
# - 11	Credit_History	Credit history of individual’s repayment of their debts
# - 12	Property_Area	Area of property i.e. Rural/Urban/Semi-urban
# - 13	Loan_Status	Status of Loan Approved or not i.e. Y- Yes, N-No

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("LoanApprovalPrediction.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            598 non-null    object
#  1   Gender             598 non-null    object
#  2   Married            598 non-null    object
#  3   Dependents         586 non-null    float64
#  4   Education          598 non-null    object
#  5   Self_Employed      598 non-null    object
#  6   ApplicantIncome    598 non-null    int64
#  7   CoapplicantIncome  598 non-null    float64
#  8   LoanAmount         577 non-null    float64
#  9   Loan_Amount_Term   584 non-null    float64
#  10  Credit_History     549 non-null    float64
#  11  Property_Area      598 non-null    object
#  12  Loan_Status        598 non-null    object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 60.9+ KB

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df['Gender'].value_counts()
# Out:
# Male      487
# Female    111
# Name: Gender, dtype: int64

# %%
#Get the number of columns of object datatype.
obj = (df.dtypes == 'object')
print("Categorical variables:",len(list(obj[obj].index)))
# Out:
# Categorical variables: 7

# %%
#As Loan_ID is completely unique and not correlated with any of the other column, So we will drop it using .drop() function.

# Dropping Loan_ID column
df.drop(['Loan_ID'],axis=1,inplace=True)

# %% [markdown]
# ### Visualize all the unique values in columns using barplot. This will simply show which value is dominating as per our dataset.

# %%
obj = (df.dtypes == 'object') 
object_cols = list(obj[obj].index) 
plt.figure(figsize=(18,36)) 
index = 1
  
for col in object_cols: 
  y = df[col].value_counts() 
  plt.subplot(11,4,index) 
  plt.xticks(rotation=90) 
  sns.barplot(x=list(y.index), y=y) 
  index +=1

# %%
#As all the categorical values are binary so we can use Label Encoder for all such columns and the values will change into int datatype.
# Import label encoder
from sklearn import preprocessing
    
# label_encoder object knows how 
# to understand word labels.
label_encoder = preprocessing.LabelEncoder()
obj = (df.dtypes == 'object')
for col in list(obj[obj].index):
    
    df[col] = label_encoder.fit_transform(df[col])

# %%
#Again check the object datatype columns. Let’s find out if there is still any left.

# To find the number of columns with 
# datatype==object
obj = (df.dtypes == 'object')
print("Categorical variables:",len(list(obj[obj].index)))
# Out:
# Categorical variables: 0

# %%
df.corr()
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.369612    0.175970   0.048478      -0.028663
# Married            0.369612  1.000000    0.350464   0.014369      -0.021441
# Dependents         0.175970  0.350464    1.000000   0.059227       0.040892
# Education          0.048478  0.014369    0.059227   1.000000      -0.015204
# Self_Employed     -0.028663 -0.021441    0.040892  -0.015204       1.000000
# ApplicantIncome    0.057386  0.042487    0.084485  -0.139349       0.140406
# CoapplicantIncome  0.083080  0.073830    0.034596  -0.065205       0.020877
# LoanAmount         0.106712  0.147602    0.131023  -0.169563       0.118304
# Loan_Amount_Term  -0.083462 -0.102360   -0.100326  -0.080760      -0.034053
# Credit_History     0.017336  0.013565   -0.046950  -0.075207       0.030774
# Property_Area     -0.025794  0.009224    0.007816  -0.061758      -0.023149
# Loan_Status        0.021239  0.093183    0.003048  -0.081617      -0.005605
#
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Gender                    0.057386           0.083080    0.106712
# Married                   0.042487           0.073830    0.147602
# Dependents                0.084485           0.034596    0.131023
# Education                -0.139349          -0.065205   -0.169563
# Self_Employed             0.140406           0.020877    0.118304
# ApplicantIncome           1.000000          -0.109235    0.529965
# CoapplicantIncome        -0.109235           1.000000    0.207045
# LoanAmount                0.529965           0.207045    1.000000
# Loan_Amount_Term         -0.035388          -0.060404    0.049346
# Credit_History           -0.031028           0.003011   -0.021177
# Property_Area            -0.023432           0.015155   -0.056637
# Loan_Status              -0.025248          -0.058194   -0.055643
#
#                    Loan_Amount_Term  Credit_History  Property_Area  \
# Gender                    -0.083462        0.017336      -0.025794
# Married                   -0.102360        0.013565       0.009224
# Dependents                -0.100326       -0.046950       0.007816
# Education                 -0.080760       -0.075207      -0.061758
# Self_Employed             -0.034053        0.030774      -0.023149
# ApplicantIncome           -0.035388       -0.031028      -0.023432
# CoapplicantIncome         -0.060404        0.003011       0.015155
# LoanAmount                 0.049346       -0.021177      -0.056637
# Loan_Amount_Term           1.000000        0.005528      -0.072521
# Credit_History             0.005528        1.000000      -0.008533
# Property_Area             -0.072521       -0.008533       1.000000
# Loan_Status               -0.017554        0.557308       0.028315
#
#                    Loan_Status
# Gender                0.021239
# Married               0.093183
# Dependents            0.003048
# Education            -0.081617
# Self_Employed        -0.005605
# ApplicantIncome      -0.025248
# CoapplicantIncome    -0.058194
# LoanAmount           -0.055643
# Loan_Amount_Term     -0.017554
# Credit_History        0.557308
# Property_Area         0.028315
# Loan_Status           1.000000

# %%
plt.figure(figsize=(12,6))
  
sns.heatmap(df.corr(),cmap='BrBG',fmt='.2f',
            linewidths=2,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Now we will use Catplot to visualize the plot for the Gender, and Marital Status of the applicant.

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Loan_Status',data=df)
plt.show()

# %%
sns.catplot(x="Gender", y="Married",
            hue="Loan_Status", 
            kind="bar", 
            data=df)

# %%
#Now we will find out if there is any missing values in the dataset using below code.
for col in df.columns:
    df[col] = df[col].fillna(df[col].mean()) 
    
df.isna().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# 1    487
# 0    111
# Name: Gender, dtype: int64

# %%
#Splitting Dataset 
from sklearn.model_selection import train_test_split
  
x = df.drop(['Loan_Status'],axis=1)
y = df['Loan_Status']
x.shape,y.shape
# Out:
# ((598, 11), (598,))

# %%
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0         0.0          0              0             5849
# 1         1        1         1.0          0              0             4583
# 2         1        1         0.0          0              1             3000
# 3         1        1         0.0          1              0             2583
# 4         1        0         0.0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 593       0        0         0.0          0              0             2900
# 594       1        1         3.0          0              0             4106
# 595       1        1         1.0          0              0             8072
# 596       1        1         2.0          0              0             7583
# 597       0        0         0.0          0              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  144.968804             360.0             1.0
# 1               1508.0  128.000000             360.0             1.0
# 2                  0.0   66.000000             360.0             1.0
# 3               2358.0  120.000000             360.0             1.0
# 4                  0.0  141.000000             360.0             1.0
# ..                 ...         ...               ...             ...
# 593                0.0   71.000000             360.0             1.0
# 594                0.0   40.000000             180.0             1.0
# 595              240.0  253.000000             360.0             1.0
# 596                0.0  187.000000             360.0             1.0
# 597                0.0  133.000000             360.0             0.0
#
#      Property_Area
# 0                2
# 1                0
# 2                2
# 3                2
# 4                2
# ..             ...
# 593              0
# 594              0
# 595              2
# 596              2
# 597              1
#
# [598 rows x 11 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 593    1
# 594    1
# 595    1
# 596    1
# 597    0
# Name: Loan_Status, Length: 598, dtype: int32

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.4,random_state=1)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((358, 11), (240, 11), (358,), (240,))

# %%
#Model Training and Evaluation
#As this is a classification problem so we will be using these models :
#KNeighborsClassifiers
#RandomForestClassifiers
#Support Vector Classifiers (SVC)
#Logistics Regression

# %%
def mymodel(model):
    model.fit(x_train,y_train)
    ypred=model.predict(x_test)
    print(classification_report(y_test,ypred))
    return model

# %%
from sklearn.metrics import accuracy_score,classification_report
from sklearn.preprocessing import StandardScaler

from sklearn.svm import SVC

# %% [markdown]
# ### # 1.---> LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(x_train,y_train)
ypred=logreg.predict(x_test)

# %%
ac=accuracy_score(y_test,ypred)
cr=classification_report(y_test,ypred)
print(ac)
print(cr)
# Out:
# 0.8
#               precision    recall  f1-score   support
#
#            0       0.78      0.48      0.59        73
#            1       0.81      0.94      0.87       167
#
#     accuracy                           0.80       240
#    macro avg       0.79      0.71      0.73       240
# weighted avg       0.80      0.80      0.78       240

# %%
logreg=LogisticRegression(solver="liblinear")
logreg.fit(x_train,y_train)
ypred=logreg.predict(x_test)

# %%
ac=accuracy_score(y_test,ypred)
cr=classification_report(y_test,ypred)
print(ac)
print(cr)
# Out:
# 0.8083333333333333
#               precision    recall  f1-score   support
#
#            0       0.81      0.48      0.60        73
#            1       0.81      0.95      0.87       167
#
#     accuracy                           0.81       240
#    macro avg       0.81      0.72      0.74       240
# weighted avg       0.81      0.81      0.79       240

# %%
logreg=LogisticRegression(solver='newton-cg')
mymodel(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.48      0.62        73
#            1       0.81      0.97      0.88       167
#
#     accuracy                           0.82       240
#    macro avg       0.84      0.72      0.75       240
# weighted avg       0.83      0.82      0.80       240
# LogisticRegression(solver='newton-cg')

# %%
logreg=LogisticRegression(solver='lbfgs')
mymodel(logreg)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.48      0.59        73
#            1       0.81      0.94      0.87       167
#
#     accuracy                           0.80       240
#    macro avg       0.79      0.71      0.73       240
# weighted avg       0.80      0.80      0.78       240
# LogisticRegression()

# %% [markdown]
# ### 2.---> SVM (Support Vector Machine)

# %%
svm=SVC()
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        73
#            1       0.69      0.99      0.82       167
#
#     accuracy                           0.69       240
#    macro avg       0.35      0.50      0.41       240
# weighted avg       0.48      0.69      0.57       240
# SVC()

# %%
svm=SVC(kernel='linear')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.45      0.57        73
#            1       0.80      0.95      0.87       167
#
#     accuracy                           0.80       240
#    macro avg       0.79      0.70      0.72       240
# weighted avg       0.79      0.80      0.78       240
# SVC(kernel='linear')

# %%
svm=SVC(kernel='poly')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.03      0.05        73
#            1       0.70      0.99      0.82       167
#
#     accuracy                           0.70       240
#    macro avg       0.68      0.51      0.44       240
# weighted avg       0.69      0.70      0.59       240
# SVC(kernel='poly')

# %%
svm=SVC(kernel='sigmoid')
mymodel(svm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.18      0.22        73
#            1       0.69      0.80      0.74       167
#
#     accuracy                           0.61       240
#    macro avg       0.49      0.49      0.48       240
# weighted avg       0.57      0.61      0.58       240
# SVC(kernel='sigmoid')

# %% [markdown]
# ## 3. KNN (K Nearest Neighbors)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
mymodel(knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.14      0.19        73
#            1       0.69      0.86      0.77       167
#
#     accuracy                           0.64       240
#    macro avg       0.49      0.50      0.48       240
# weighted avg       0.57      0.64      0.59       240
# KNeighborsClassifier()

# %%
knn=KNeighborsClassifier(n_neighbors=3)
mymodel(knn)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.26      0.30        73
#            1       0.71      0.80      0.75       167
#
#     accuracy                           0.64       240
#    macro avg       0.54      0.53      0.53       240
# weighted avg       0.61      0.64      0.62       240
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ## 4. Decision Tree (DT)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
dt=DecisionTreeClassifier()

# %%
mymodel(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.55      0.53        73
#            1       0.80      0.77      0.78       167
#
#     accuracy                           0.70       240
#    macro avg       0.65      0.66      0.65       240
# weighted avg       0.71      0.70      0.70       240
# DecisionTreeClassifier()

# %%
fig,ax=plt.subplots(figsize=(30,20))
chart=tree.plot_tree(dt,max_depth=5,feature_names=x.columns,filled=True,fontsize=10)
plt.savefig('abc.jpg')

# %%
train=dt.score(x_train,y_train)
test=dt.score(x_test,y_test)
print(f'train score :{train} \ntest score: {test}')
# Out:
# train score :1.0
# test score: 0.7

# %%
for i in range(1,50):
    dt1=DecisionTreeClassifier(max_depth=i)
    dt1.fit(x_train,y_train)
    ypred=dt1.predict(x_test)
    ac=accuracy_score(y_test,ypred)
    print(f"max_depth:{i} Accuracy: {ac}")
# Out:
# max_depth:1 Accuracy: 0.8208333333333333
# max_depth:2 Accuracy: 0.8166666666666667
# max_depth:3 Accuracy: 0.7166666666666667
# max_depth:4 Accuracy: 0.775
# max_depth:5 Accuracy: 0.75
# max_depth:6 Accuracy: 0.7416666666666667
# max_depth:7 Accuracy: 0.6875
# max_depth:8 Accuracy: 0.7166666666666667
# max_depth:9 Accuracy: 0.6958333333333333
# max_depth:10 Accuracy: 0.7083333333333334
# max_depth:11 Accuracy: 0.6791666666666667
# max_depth:12 Accuracy: 0.6958333333333333
# max_depth:13 Accuracy: 0.6875
# max_depth:14 Accuracy: 0.7
# max_depth:15 Accuracy: 0.6875
# max_depth:16 Accuracy: 0.6833333333333333
# max_depth:17 Accuracy: 0.6958333333333333
# max_depth:18 Accuracy: 0.6625
# max_depth:19 Accuracy: 0.6875
# max_depth:20 Accuracy: 0.6875
# max_depth:21 Accuracy: 0.6833333333333333
# max_depth:22 Accuracy: 0.6791666666666667
# max_depth:23 Accuracy: 0.7
# max_depth:24 Accuracy: 0.6916666666666667
# max_depth:25 Accuracy: 0.6958333333333333
# max_depth:26 Accuracy: 0.7041666666666667
# max_depth:27 Accuracy: 0.6875
# max_depth:28 Accuracy: 0.7041666666666667
# max_depth:29 Accuracy: 0.6958333333333333
# max_depth:30 Accuracy: 0.7041666666666667
# max_depth:31 Accuracy: 0.6916666666666667
# max_depth:32 Accuracy: 0.7
# max_depth:33 Accuracy: 0.7083333333333334
# max_depth:34 Accuracy: 0.7041666666666667
# max_depth:35 Accuracy: 0.7041666666666667
# max_depth:36 Accuracy: 0.6916666666666667
# max_depth:37 Accuracy: 0.7
# max_depth:38 Accuracy: 0.6666666666666666
# max_depth:39 Accuracy: 0.6666666666666666
# max_depth:40 Accuracy: 0.6791666666666667
# max_depth:41 Accuracy: 0.7125
# max_depth:42 Accuracy: 0.6916666666666667
# max_depth:43 Accuracy: 0.7166666666666667
# max_depth:44 Accuracy: 0.7083333333333334
# max_depth:45 Accuracy: 0.6875
# max_depth:46 Accuracy: 0.6916666666666667
# max_depth:47 Accuracy: 0.7
# max_depth:48 Accuracy: 0.6833333333333333
# max_depth:49 Accuracy: 0.6708333333333333

# %%
dt2=DecisionTreeClassifier(max_depth=29)
mymodel(dt2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.48      0.48        73
#            1       0.77      0.77      0.77       167
#
#     accuracy                           0.68       240
#    macro avg       0.63      0.63      0.63       240
# weighted avg       0.68      0.68      0.68       240
# DecisionTreeClassifier(max_depth=29)

# %%
train=dt2.score(x_train,y_train)
test=dt2.score(x_test,y_test)
print(f'train score :{train} \ntest score: {test}')
# Out:
# train score :1.0
# test score: 0.6833333333333333

# %%
for i in range(10,200):
    dt3=DecisionTreeClassifier(min_samples_split=i)
    dt3.fit(x_train,y_train)
    ypred=dt3.predict(x_test)
    ac=accuracy_score(y_test,ypred)
    print(f'min_samples_split: {i} Accuracy: {ac}')
# Out:
# min_samples_split: 10 Accuracy: 0.7
# min_samples_split: 11 Accuracy: 0.6833333333333333
# min_samples_split: 12 Accuracy: 0.6708333333333333
# min_samples_split: 13 Accuracy: 0.6791666666666667
# min_samples_split: 14 Accuracy: 0.675
# min_samples_split: 15 Accuracy: 0.6791666666666667
# min_samples_split: 16 Accuracy: 0.6875
# min_samples_split: 17 Accuracy: 0.6916666666666667
# min_samples_split: 18 Accuracy: 0.6916666666666667
# min_samples_split: 19 Accuracy: 0.6791666666666667
# min_samples_split: 20 Accuracy: 0.6916666666666667
# min_samples_split: 21 Accuracy: 0.6833333333333333
# min_samples_split: 22 Accuracy: 0.6916666666666667
# min_samples_split: 23 Accuracy: 0.6958333333333333
# min_samples_split: 24 Accuracy: 0.6958333333333333
# min_samples_split: 25 Accuracy: 0.7166666666666667
# min_samples_split: 26 Accuracy: 0.7333333333333333
# min_samples_split: 27 Accuracy: 0.7333333333333333
# min_samples_split: 28 Accuracy: 0.7416666666666667
# min_samples_split: 29 Accuracy: 0.7416666666666667
# min_samples_split: 30 Accuracy: 0.7416666666666667
# min_samples_split: 31 Accuracy: 0.7416666666666667
# min_samples_split: 32 Accuracy: 0.7416666666666667
# min_samples_split: 33 Accuracy: 0.7416666666666667
# min_samples_split: 34 Accuracy: 0.7416666666666667
# min_samples_split: 35 Accuracy: 0.7416666666666667
# min_samples_split: 36 Accuracy: 0.7416666666666667
# min_samples_split: 37 Accuracy: 0.7416666666666667
# min_samples_split: 38 Accuracy: 0.7416666666666667
# min_samples_split: 39 Accuracy: 0.7583333333333333
# min_samples_split: 40 Accuracy: 0.7583333333333333
# min_samples_split: 41 Accuracy: 0.7583333333333333
# min_samples_split: 42 Accuracy: 0.7583333333333333
# min_samples_split: 43 Accuracy: 0.7041666666666667
# min_samples_split: 44 Accuracy: 0.7041666666666667
# min_samples_split: 45 Accuracy: 0.7041666666666667
# min_samples_split: 46 Accuracy: 0.7041666666666667
# min_samples_split: 47 Accuracy: 0.7041666666666667
# min_samples_split: 48 Accuracy: 0.7041666666666667
# min_samples_split: 49 Accuracy: 0.7041666666666667
# min_samples_split: 50 Accuracy: 0.7041666666666667
# min_samples_split: 51 Accuracy: 0.7083333333333334
# min_samples_split: 52 Accuracy: 0.7083333333333334
# min_samples_split: 53 Accuracy: 0.7083333333333334
# min_samples_split: 54 Accuracy: 0.7083333333333334
# min_samples_split: 55 Accuracy: 0.7083333333333334
# min_samples_split: 56 Accuracy: 0.7083333333333334
# min_samples_split: 174 Accuracy: 0.8208333333333333
# min_samples_split: 175 Accuracy: 0.8208333333333333
# min_samples_split: 176 Accuracy: 0.8208333333333333
# min_samples_split: 177 Accuracy: 0.8208333333333333
# min_samples_split: 178 Accuracy: 0.8208333333333333
# min_samples_split: 179 Accuracy: 0.8208333333333333
# min_samples_split: 180 Accuracy: 0.8208333333333333
# min_samples_split: 181 Accuracy: 0.8208333333333333
# min_samples_split: 182 Accuracy: 0.8208333333333333
# min_samples_split: 183 Accuracy: 0.8208333333333333
# min_samples_split: 184 Accuracy: 0.8208333333333333
# min_samples_split: 185 Accuracy: 0.8208333333333333
# min_samples_split: 186 Accuracy: 0.8208333333333333
# min_samples_split: 187 Accuracy: 0.8208333333333333
# min_samples_split: 188 Accuracy: 0.8208333333333333
# min_samples_split: 189 Accuracy: 0.8208333333333333
# min_samples_split: 190 Accuracy: 0.8208333333333333
# min_samples_split: 191 Accuracy: 0.8208333333333333
# min_samples_split: 192 Accuracy: 0.8208333333333333
# min_samples_split: 193 Accuracy: 0.8208333333333333
# min_samples_split: 194 Accuracy: 0.8208333333333333
# min_samples_split: 195 Accuracy: 0.8208333333333333
# min_samples_split: 196 Accuracy: 0.8208333333333333
# min_samples_split: 197 Accuracy: 0.8208333333333333
# min_samples_split: 198 Accuracy: 0.8208333333333333
# min_samples_split: 199 Accuracy: 0.8208333333333333

# %%
dt6=DecisionTreeClassifier(min_samples_split=72)
mymodel(dt6)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.48      0.62        73
#            1       0.81      0.97      0.88       167
#
#     accuracy                           0.82       240
#    macro avg       0.84      0.72      0.75       240
# weighted avg       0.83      0.82      0.80       240
# DecisionTreeClassifier(min_samples_split=72)

# %%
train=dt6.score(x_train,y_train)
test=dt6.score(x_test,y_test)
print(f'train score :{train} \ntest score: {test}')
# Out:
# train score :0.8100558659217877
# test score: 0.8208333333333333

# %% [markdown]
# ## ---> Bagging

# %%
from sklearn.ensemble import BaggingClassifier
bg=BaggingClassifier(LogisticRegression())
bg.fit(x_train,y_train)
ypred=bg.predict(x_test)
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.48      0.62        73
#            1       0.81      0.97      0.88       167
#
#     accuracy                           0.82       240
#    macro avg       0.84      0.72      0.75       240
# weighted avg       0.83      0.82      0.80       240

# %%
bg=BaggingClassifier(DecisionTreeClassifier())
bg.fit(x_train,y_train)
ypred=bg.predict(x_test)
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64        73
#            1       0.84      0.84      0.84       167
#
#     accuracy                           0.78       240
#    macro avg       0.74      0.74      0.74       240
# weighted avg       0.78      0.78      0.78       240

# %% [markdown]
# ###  Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rc=RandomForestClassifier()
rc.fit(x_train,y_train)
ypred=rc.predict(x_test)
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.51      0.61        73
#            1       0.81      0.93      0.87       167
#
#     accuracy                           0.80       240
#    macro avg       0.79      0.72      0.74       240
# weighted avg       0.80      0.80      0.79       240

# %%
rc=RandomForestClassifier(n_estimators=7,criterion="entropy",random_state=7)
mymodel(rc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.62      0.68        73
#            1       0.85      0.92      0.88       167
#
#     accuracy                           0.82       240
#    macro avg       0.80      0.77      0.78       240
# weighted avg       0.82      0.82      0.82       240
# RandomForestClassifier(criterion='entropy', n_estimators=7, random_state=7)
